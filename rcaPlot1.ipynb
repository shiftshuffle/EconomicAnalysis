# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import plotly.figure_factory as ff

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def count_products(rca_treshold,rca_dataframe):
    return len(rca_dataframe[rca_dataframe.rca > rca_treshold])

def plot_x(x,country_name):
    return list(map(lambda x: count_products(x,rca_df[rca_df.exporter == country_name]),x))

# %%
df = pd.read_csv("../data/wtf.csv")
df['sitc4'] = df['sitc4'].astype(str)
del df['Unnamed: 0']

gdf = df.groupby(["sitc4","exporter"]).sum().reset_index()
gdf = gdf[['sitc4','exporter','value']]

rca_df = pd.read_csv("../data/rca.csv")
del rca_df['Unnamed: 0']
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning:
#
# Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
all_countries = list(gdf.exporter.unique())
all_countries
# Out:
# ['Areas NES',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium-Lux',
#  'Belize',
#  'Brazil',
#  'Bulgaria',
#  'Cambodia',
#  'Canada',
#  'China',
#  'Czech Rep',
#  'Denmark',
#  'Ecuador',
#  'Egypt',
#  'Estonia',
#  'France,Monac',
#  'Germany',
#  'Greece',
#  'Honduras',
#  'Hungary',
#  'Ireland',
#  'Italy',
#  'Jordan',
#  'Lao P.Dem.R',
#  'Lithuania',
#  'Mexico',
#  'Myanmar',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Norway',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russian Fed',
#  'Singapore',
#  'Slovakia',
#  'South Africa',
#  'Spain',
#  'Sweden',
#  'Thailand',
#  'UK',
#  'USA',
#  'Untd Arab Em',
#  'Uruguay',
#  'World',
#  'Djibouti',
#  'Ethiopia',
#  'Iran',
#  'Lebanon',
#  'Oman',
#  'Qatar',
#  'Saudi Arabia',
#  'Somalia',
#  'Sudan',
#  'Syria',
#  'Turkey',
#  'Uganda',
#  'Yemen',
#  'Algeria',
#  'Chile',
#  'Cyprus',
#  'Finland',
#  'Indonesia',
#  'Korea Rep.',
#  'Mali',
# ...

# %%
rca_df
# Out:
#       sitc4      exporter  value         rca
# 0      0011     Areas NES    388    0.112449
# 1      0015     Areas NES  39012   23.301008
# 2      001X     Areas NES     30   54.200398
# 3      0111     Areas NES   3110    0.269048
# 4      0112     Areas NES   1738    0.996977
# ...     ...           ...    ...         ...
# 62398  7449  Eur.Other NE    496    9.559791
# 62399  7919  Eur.Other NE   2110  143.167907
# 62400  5416      CACM NES    518  553.623273
# 62401  6841  Br.Antr.Terr   2262  251.251165
# 62402  9310     Fr.Guiana   4258   57.410065
#
# [62403 rows x 4 columns]

# %%
rca_df[rca_df.exporter == "Germany"]
# Out:
#       sitc4 exporter   value       rca
# 11594  0011  Germany  480665  0.766075
# 11595  0012  Germany    9062  0.080920
# 11596  0013  Germany  110101  0.531726
# 11597  0014  Germany  219144  1.689528
# 11598  0015  Germany  114507  0.376109
# ...     ...      ...     ...       ...
# 12599  9410  Germany    5804  0.179269
# 12600  9510  Germany  309868  0.933478
# 12601  9610  Germany    2656  0.022667
# 12602  9710  Germany  445956  0.537908
# 12603   980  Germany  583553  1.178282
#
# [1010 rows x 4 columns]

# %%
count_products(1,rca_df[rca_df.exporter == "Germany"])
# Out:
# 473

# %%
x =np.linspace(0.001,1,num=100)
x
# Out:
# array([0.001     , 0.01109091, 0.02118182, 0.03127273, 0.04136364,
#        0.05145455, 0.06154545, 0.07163636, 0.08172727, 0.09181818,
#        0.10190909, 0.112     , 0.12209091, 0.13218182, 0.14227273,
#        0.15236364, 0.16245455, 0.17254545, 0.18263636, 0.19272727,
#        0.20281818, 0.21290909, 0.223     , 0.23309091, 0.24318182,
#        0.25327273, 0.26336364, 0.27345455, 0.28354545, 0.29363636,
#        0.30372727, 0.31381818, 0.32390909, 0.334     , 0.34409091,
#        0.35418182, 0.36427273, 0.37436364, 0.38445455, 0.39454545,
#        0.40463636, 0.41472727, 0.42481818, 0.43490909, 0.445     ,
#        0.45509091, 0.46518182, 0.47527273, 0.48536364, 0.49545455,
#        0.50554545, 0.51563636, 0.52572727, 0.53581818, 0.54590909,
#        0.556     , 0.56609091, 0.57618182, 0.58627273, 0.59636364,
#        0.60645455, 0.61654545, 0.62663636, 0.63672727, 0.64681818,
#        0.65690909, 0.667     , 0.67709091, 0.68718182, 0.69727273,
# ...

# %%
y = list(map(lambda x: count_products(x,rca_df[rca_df.exporter == "Germany"]), x))
y
# Out:
# [1010,
#  1003,
#  996,
#  988,
#  982,
#  973,
#  966,
#  956,
#  952,
#  946,
#  938,
#  933,
#  926,
#  920,
#  908,
#  902,
#  896,
#  888,
#  880,
#  872,
#  866,
#  859,
#  855,
#  849,
#  838,
#  833,
#  828,
#  822,
#  816,
#  808,
#  804,
#  794,
#  789,
#  781,
#  776,
#  769,
#  766,
#  759,
#  755,
#  744,
#  738,
#  734,
#  726,
#  719,
#  713,
#  708,
#  705,
#  703,
#  695,
#  691,
#  682,
#  675,
#  672,
#  667,
#  659,
#  657,
#  653,
#  649,
#  642,
#  637,
#  637,
#  633,
#  627,
#  620,
#  615,
#  607,
#  601,
#  598,
#  593,
#  587,
#  582,
#  581,
#  576,
#  572,
#  567,
#  566,
#  561,
#  556,
#  555,
#  551,
#  545,
#  535,
#  533,
#  531,
#  530,
#  526,
#  522,
#  519,
#  514,
#  506,
#  503,
#  500,
#  500,
#  493,
#  487,
#  486,
#  482,
#  478,
#  477,
#  473]

# %%
figure =[]
for country in all_countries:
    figure.append(go.Scatter(name=country, x=x, y=plot_x(x,country),mode='lines',line=dict(width=1),showlegend=True))

fig = go.Figure(figure)
fig.show()
# Out:
# <div>                            <div id="74a9dbf9-f6e3-4188-8f94-91c48853bedc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a9dbf9-f6e3-4188-8f94-91c48853bedc")) {                    Plotly.newPlot(                        "74a9dbf9-f6e3-4188-8f94-91c48853bedc",                        [{"line": {"width": 1}, "mode": "lines", "name": "Areas NES", "showlegend": true, "type": "scatter", "x": [0.001, 0.011090909090909092, 0.021181818181818184, 0.03127272727272727, 0.041363636363636366, 0.05145454545454546, 0.06154545454545455, 0.07163636363636364, 0.08172727272727273, 0.09181818181818183, 0.10190909090909092, 0.112, 0.1220909090909091, 0.13218181818181818, 0.14227272727272727, 0.15236363636363637, 0.16245454545454546, 0.17254545454545456, 0.1826363
# ...

# %%
fig = go.Figure([
    go.Scatter(
        name='Germany',
        x=x,
        y=list(map(lambda x: count_products(x,rca_df[rca_df.exporter == "Germany"]), x)),
        mode='lines',
        #marker=dict(color='red'),
        line=dict(width=1),
        showlegend=True
    ),
    go.Scatter(
        name='Mexico',
        x=x,
        y=list(map(lambda x: count_products(x,rca_df[rca_df.exporter == "Mexico"]), x)),
        mode='lines',
        #marker=dict(color="#444"),
        line=dict(width=1),
        showlegend=True
    )])

fig.show()
# Out:
# <div>                            <div id="bbd5a85f-f63b-4a36-b0f7-d30e4225012c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbd5a85f-f63b-4a36-b0f7-d30e4225012c")) {                    Plotly.newPlot(                        "bbd5a85f-f63b-4a36-b0f7-d30e4225012c",                        [{"line": {"width": 1}, "mode": "lines", "name": "Germany", "showlegend": true, "type": "scatter", "x": [0.0, 0.7777777777777778, 1.5555555555555556, 2.3333333333333335, 3.111111111111111, 3.888888888888889, 4.666666666666667, 5.444444444444445, 6.222222222222222, 7.0], "y": [1010, 556, 283, 132, 60, 47, 28, 21, 15, 12]}, {"line": {"width": 1}, "mode": "lines", "name": "Mexico", "showlegend": true, "type": "scatter", "x": [0.0, 0.7777777777777778, 1.55555555555555
# ...
